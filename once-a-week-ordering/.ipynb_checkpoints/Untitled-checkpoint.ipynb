# %%
import pandas as pd

# %%
#import csv
df_rx = pd.read_csv('RXPORTE_20170426_114606.csv')
df_prod = pd.read_csv('Product_Export_20170426_114857.csv')

#format dataframes before merging
df_rx['rxid'] = df_rx['Rx Number']
df_rx['date'] = pd.to_datetime(df_rx['Date Written'], format='%m%d%Y')
# df_rx['ndc'] = pd.np.abs(df_rx['Dispensed NDC #'].astype(int))
df_rx['ndc'] = df_rx['Dispensed NDC #']
df_rx['qty'] = df_rx['Refill Qty'].astype(int)
df_rx['days_supply'] = pd.to_numeric(df_rx['Days Supply'],errors='coerce').astype(int)


df_prod['gcsn'] = df_prod['dg-generic-code-seq-nbr']
df_prod['pkg_size'] = df_prod['dg-pkg-size-units']
df_prod['units'] = df_prod['dg-dispensing-units']
df_prod['desc'] = df_prod['dg-description']
df_prod['gen_desc'] = df_prod['dg-description-generic']
df_prod['ppc'] = df_prod['dg-preferred-product-code'].fillna(0)
df_prod['ndc'] = df_prod['dg-ndc']
df_prod['qoh'] = pd.to_numeric(df_prod['dg-qty-on-hand'],errors='coerce').fillna(0).astype(int)
df_prod['reorder_point'] = df_prod["dg-reorder-point"]
df_prod['reorder_qoh_desired'] = df_prod["dg-qty-on-hand-desired"]
df_prod['reorder_qty'] = df_prod["dg-qty-reorder"]


#trim product DF and merge with rx DF
df_all = df_rx.merge(df_prod,how='left',on='ndc')

#trim to relevent columns
df_final = df_all.loc[:,['rxid','date','desc','ndc','qty','days_supply','gcsn','pkg_size','units','gen_desc','ppc','qoh']]
df_final.loc[:,'qty_per_day'] = df_final.loc[:,'qty']/df_final.loc[:,'days_supply']
df_final.dropna(subset=['gcsn','ndc'],inplace=True)

# %% [markdown]
# # Perform aggregation

# %%
def agg_sum(df,cols,val_col='qty',func=sum):
    return df.groupby(cols + ['date'])[val_col].apply(func).unstack(level=cols).sort_index().sort_index(axis=1)

# %% [markdown]
# ## First question:
#
# For each item on formulary, i.e. each gcsn with a ppc set to 1 for SOME NDC, what is the:
# 1. Current preffered product info
#     - package size (pkg_size)
#     - unit (units)
# 2. Information on that product/gcsn:
#     - Number of Rx dispensed
#     - total units dispense
# 3. PER RX statistic:
#     - max qty
#     - mean qty
#     - quartiles (25%, 50%, 75%)
#     - max qty/days_supply
#     - mean qty/days_supply
# 3. PER CLINIC statistics:
#     - Number of Rx dispensed
#     - max qty
#     - mean qty
#     - quartiles (25%, 50%, 75%)

# %% [markdown]
# ## 1. Prefferred Product info

# %%
df_ppc = df_prod.loc[df_prod.groupby('gcsn')['ppc'].idxmax()]
is_ppc_reorder  = ~(pd.isnull(df_prod["dg-qty-on-hand-desired"]) & pd.isnull(df_prod["dg-qty-reorder"])) & (df_prod["ppc"] == 1)
df_ppc = df_ppc.loc[is_ppc_reorder]
df_ppc = df_ppc[['ndc','gcsn','desc','pkg_size','units','reorder_point','reorder_qty','reorder_qoh_desired']]
df_ppc.set_index('gcsn', inplace=True)
df_ppc.columns = pd.MultiIndex.from_tuples([('pp_info',col) for col in df_ppc.columns])
print df_ppc.shape
df_ppc.head()
# Out:
# (254, 4)
#             pp_info
#                 ndc                            desc pkg_size units
# gcsn
# 266.0  6.838202e+10  AMIODARONE HCL 200 MG TABLEZYD      500    TA
# 287.0  5.011103e+10    HYDRALAZINE 50 MG TABLET PLI      100    TA
# 346.0  2.282128e+08  CLONIDINE HCL 0.1 MG TABLETACT      500    TA
# 390.0  1.850610e+08     LISINOPRIL 10 MG TABLET SAN     1000    TA
# 391.0  1.850620e+08     LISINOPRIL 20 MG TABLET SAN     1000    TA

# %% [markdown]
# ## 2. Information on GCSN

# %%
cnt = df_final.groupby('gcsn').date.count()
cnt.name = 'rx_count'
cnt=cnt.to_frame()
total = df_final.groupby('gcsn').qty.sum()
total.name = 'tot_units'
total=total.to_frame()
qoh = df_prod.groupby('gcsn').qoh.sum()
qoh.name = 'qoh'
qoh=qoh.to_frame()
df_gcsn_agg = cnt.join(total,how='outer')
df_gcsn_agg = df_gcsn_agg.join(qoh,how='outer').fillna(0).sort_values('rx_count')

df_gcsn_agg.columns = pd.MultiIndex.from_tuples([('gcsn_totals',col) for col in df_gcsn_agg.columns])
df_gcsn_agg.head()
# Out:
#         gcsn_totals
#            rx_count tot_units qoh
# gcsn
# 23725.0         0.0       0.0   2
# 7284.0          0.0       0.0  15
# 57803.0         0.0       0.0   0
# 57802.0         0.0       0.0   0
# 33515.0         0.0       0.0   0

# %% [markdown]
# ## 3. Per RX statistics
# - max qty
# - mean qty
# - quartiles (25%, 50%, 75%)
# - max qty/days_supply
# - mean qty/days_supply

# %%
df_per_rx = df_final.groupby(['gcsn'])['qty','qty_per_day'].describe().unstack(-1)
to_keep = [('qty','mean'),('qty','25%'),('qty','50%'),('qty','75%'),('qty','max'),('qty_per_day','mean'),('qty_per_day','max')]
df_per_rx = df_per_rx[to_keep]
df_per_rx.columns.set_levels(levels=['units_per_rx','rx_units_per_day'], level=0,inplace=True)
df_per_rx.head()
# Out:
#       units_per_rx                              rx_units_per_day
#               mean     25%    50%    75%    max             mean  max
# gcsn
# 266.0    60.000000   30.00   60.0   90.0   90.0         1.000000  1.0
# 346.0   180.000000  180.00  180.0  180.0  180.0         2.000000  2.0
# 390.0    71.029412   54.75   90.0   90.0  200.0         1.014706  2.0
# 391.0    77.941176   49.25   90.0   90.0  180.0         1.103268  2.0
# 392.0    73.126761   60.00   90.0   90.0  150.0         1.000000  1.0

# %% [markdown]
# ## 4. Per CLINIC statistics
#
# - Number of Rx dispensed
# - max qty
# - mean qty
# - quartiles (25%, 50%, 75%)

# %%
df_pc_cnt = df_final.groupby(['gcsn','date'])['qty'].count().unstack(-1).T.describe().T[['mean','max']]
df_pc_cnt.columns = ['rx_cnt_mean','rx_cnt_max']
df_pc_cnt.head()
# Out:
#        rx_cnt_mean  rx_cnt_max
# gcsn
# 266.0     1.333333         2.0
# 346.0     1.000000         1.0
# 390.0     1.307692         3.0
# 391.0     1.837838         6.0
# 392.0     1.690476         5.0

# %%
df_pc_rx = df_final.groupby(['gcsn','date'])['qty'].sum().unstack(-1).T.describe().T
df_pc_rx.drop('count',inplace=True,axis=1)
df_pc_rx.head()
# Out:
#              mean        std    min    25%    50%    75%    max
# gcsn
# 266.0   80.000000  17.320508   60.0   75.0   90.0   90.0   90.0
# 346.0  180.000000   0.000000  180.0  180.0  180.0  180.0  180.0
# 390.0   92.884615  56.782622    7.0   60.0   90.0   90.0  260.0
# 391.0  143.243243  80.066433    7.0   90.0  120.0  180.0  300.0
# 392.0  123.619048  75.776936    7.0   90.0   90.0  180.0  280.0

# %%
df_per_clinic = df_pc_rx.join(df_pc_cnt)
df_per_clinic.columns = pd.MultiIndex.from_tuples([('per_clinic',col) for col in df_per_clinic.columns])
df_per_clinic.head()
# Out:
#        per_clinic                                                            \
#              mean        std    min    25%    50%    75%    max rx_cnt_mean
# gcsn
# 266.0   80.000000  17.320508   60.0   75.0   90.0   90.0   90.0    1.333333
# 346.0  180.000000   0.000000  180.0  180.0  180.0  180.0  180.0    1.000000
# 390.0   92.884615  56.782622    7.0   60.0   90.0   90.0  260.0    1.307692
# 391.0  143.243243  80.066433    7.0   90.0  120.0  180.0  300.0    1.837838
# 392.0  123.619048  75.776936    7.0   90.0   90.0  180.0  280.0    1.690476
#
#
#       rx_cnt_max
# gcsn
# 266.0        2.0
# 346.0        1.0
# 390.0        3.0
# 391.0        6.0
# 392.0        5.0

# %%
df_rx_info = df_ppc
df_rx_info = df_rx_info.join(df_gcsn_agg,how='left')
df_rx_info = df_rx_info.join(df_per_rx,how='left')
df_rx_info = df_rx_info.join(df_per_clinic,how='left')
df_rx_info.head()
# Out:
# gcsn                                                   266.0  \
# pp_info          ndc                              6.8382e+10
#                  desc         AMIODARONE HCL 200 MG TABLEZYD
#                  pkg_size                                500
#                  units                                    TA
# gcsn_totals      rx_count                                  4
#                  tot_units                               240
#                  qoh                                      90
# units_per_rx     mean                                     60
#                  25%                                      30
#                  50%                                      60
#                  75%                                      90
#                  max                                      90
# rx_units_per_day mean                                      1
#                  max                                       1
# per_clinic       mean                                     80
#                  std                                 17.3205
#                  min                                      60
#                  25%                                      75
#                  50%                                      90
#                  75%                                      90
#                  max                                      90
#                  rx_cnt_mean                         1.33333
#                  rx_cnt_max                                2
#
# gcsn                                                 287.0  \
# pp_info          ndc                            5.0111e+10
#                  desc         HYDRALAZINE 50 MG TABLET PLI
#                  pkg_size                              100
#                  units                                  TA
# gcsn_totals      rx_count                                0
#                  tot_units                               0
#                  qoh                                   500
# units_per_rx     mean                                  NaN
#                  25%                                   NaN
#                  50%                                   NaN
#                  75%                                   NaN
#                  max                                   NaN
# rx_units_per_day mean                                  NaN
#                  max                                   NaN
# per_clinic       mean                                  NaN
#                  std                                   NaN
#                  min                                   NaN
#                  25%                                   NaN
#                  50%                                   NaN
#                  75%                                   NaN
#                  max                                   NaN
#                  rx_cnt_mean                           NaN
#                  rx_cnt_max                            NaN
#
# gcsn                                                   346.0  \
# pp_info          ndc                             2.28213e+08
#                  desc         CLONIDINE HCL 0.1 MG TABLETACT
#                  pkg_size                                500
#                  units                                    TA
# gcsn_totals      rx_count                                  2
#                  tot_units                               360
#                  qoh                                     160
# units_per_rx     mean                                    180
#                  25%                                     180
#                  50%                                     180
#                  75%                                     180
#                  max                                     180
# rx_units_per_day mean                                      2
#                  max                                       2
# per_clinic       mean                                    180
#                  std                                       0
#                  min                                     180
#                  25%                                     180
#                  50%                                     180
#                  75%                                     180
#                  max                                     180
#                  rx_cnt_mean                               1
#                  rx_cnt_max                                1
#
# gcsn                                                390.0  \
# pp_info          ndc                          1.85061e+08
#                  desc         LISINOPRIL 10 MG TABLET SAN
#                  pkg_size                            1000
#                  units                                 TA
# gcsn_totals      rx_count                              34
#                  tot_units                           2415
#                  qoh                                 2410
# units_per_rx     mean                             71.0294
#                  25%                                54.75
#                  50%                                   90
#                  75%                                   90
#                  max                                  200
# rx_units_per_day mean                             1.01471
#                  max                                    2
# per_clinic       mean                             92.8846
#                  std                              56.7826
#                  min                                    7
#                  25%                                   60
#                  50%                                   90
#                  75%                                   90
#                  max                                  260
#                  rx_cnt_mean                      1.30769
#                  rx_cnt_max                             3
#
# gcsn                                                391.0
# pp_info          ndc                          1.85062e+08
#                  desc         LISINOPRIL 20 MG TABLET SAN
#                  pkg_size                            1000
#                  units                                 TA
# gcsn_totals      rx_count                              68
#                  tot_units                           5300
#                  qoh                                 3217
# units_per_rx     mean                             77.9412
#                  25%                                49.25
#                  50%                                   90
#                  75%                                   90
#                  max                                  180
# rx_units_per_day mean                             1.10327
#                  max                                    2
# per_clinic       mean                             143.243
#                  std                              80.0664
#                  min                                    7
#                  25%                                   90
#                  50%                                  120
#                  75%                                  180
#                  max                                  300
#                  rx_cnt_mean                      1.83784
#                  rx_cnt_max                             6

# %%
df_rx_info.to_excel
# Out:
#               pp_info                                                 \
#                   ndc                            desc pkg_size units
# gcsn
# 266.0    6.838202e+10  AMIODARONE HCL 200 MG TABLEZYD      500    TA
# 287.0    5.011103e+10    HYDRALAZINE 50 MG TABLET PLI      100    TA
# 346.0    2.282128e+08  CLONIDINE HCL 0.1 MG TABLETACT      500    TA
# 390.0    1.850610e+08     LISINOPRIL 10 MG TABLET SAN     1000    TA
# 391.0    1.850620e+08     LISINOPRIL 20 MG TABLET SAN     1000    TA
# 392.0    3.782076e+08     LISINOPRIL 40 MG TABLET MYL      500    TA
# 393.0    1.855400e+08      LISINOPRIL 5 MG TABLET SAN     1000    TA
# 475.0    4.359804e+10  NITROGLYCERIN 0.4 MG TABLETDR.      100    TA
# 564.0    5.910345e+08     VERAPAMIL 120 MG TABLET WAT      500    TA
# 566.0    5.910343e+08      VERAPAMIL 80 MG TABLET WAT     1000    TA
# 573.0    9.303210e+07     DILTIAZEM 120 MG TABLET TEV      100    TA
# 1275.0   7.478042e+07      K-TAB ER 10 MEQ TABLET ABB     1000    TA
# 1276.0   7.430231e+07      K-TAB ER 20 MEQ TABLET ABB      100    TA
# 1408.0   5.164508e+10  MAGNESIUM OXIDE 400 MG TABLPPI      120    TA
# 1645.0   9.047591e+08  FERROUS SULFATE 325 MG TABLMAJ     1000    TA
# 1774.0   9.383430e+07     GLYBURIDE 2.5 MG TABLET TEV      500    TA
# 1775.0   9.383440e+07       GLYBURIDE 5 MG TABLET TEV      500    TA
# 1990.0   4.096648e+08     DEXTROSE 50%-WATER VIAL HOS       50    ML
# 2151.0   9.040524e+08     VITAMIN C 500 MG TABLET MAJ     1000    TA
# 2169.0   5.766401e+10  VIT D2 1.25 MG (50,000 UNITCAR      100    CA
# 2184.0   5.400072e+07  CALCITRIOL 0.25 MCG CAPSULEROX      100    CA
# 2329.0   6.332300e+10  CYANOCOBALAMIN 1,000 MCG/MLAPP        1    ML
# 2336.0   9.041132e+08  VITAMIN B-12 100 MCG TABLETMAJ      130    TA
# 2337.0   9.044217e+08  VITAMIN B-12 1,000 MCG TABLMAJ      130    TA
# 2366.0   6.033162e+08      FOLIC ACID 1 MG TABLET QUA     1000    TA
# 2391.0   9.042273e+08        NIACIN 500 MG TABLET MAJ      100    TA
# 2421.0   9.040519e+08   VITAMIN B-6 100 MG TABLET MAJ      100    TA
# 2451.0   9.040545e+08   VITAMIN B-1 100 MG TABLET MAJ     1000    TA
# 2532.0   5.364046e+08        MULTIVITAMINS TABLET RUG     1000    TA
# 2535.0   1.671400e+10   ALLOPURINOL 100 MG TABLET NOR      100    TA
# ...               ...                             ...      ...   ...
# 46237.0  6.050502e+10  BUPROPION HCL 100 MG TABLETAPO      100    TA
# 46238.0  4.359805e+10  BUPROPION HCL SR 150 MG TABDR.      500    TA
# 46239.0  1.850410e+08  BUPROPION HCL SR 100 MG TABSAN      100    TA
# 46241.0  4.229108e+10       TRAZODONE 50 MG TABLET AV     1000    TA
# 46242.0  6.036161e+08     TRAZODONE 100 MG TABLET QUA     1000    TA
# 46403.0  9.373850e+07  VENLAFAXINE HCL ER 37.5 MG TEV       90    CA
# 46405.0  9.373870e+07  VENLAFAXINE HCL ER 150 MG CTEV       90    CA
# 46450.0  5.107901e+10    MIRTAZAPINE 15 MG TABLET UDL      300    TA
# 46754.0  6.787702e+10  METFORMIN HCL ER 500 MG TABASC      500    TA
# 47400.0  3.839605e+10  DEX4 GLUCOSE 4 GM TABLET CHCAN       10    TA
# 48544.0  2.420808e+10  NEOMYC-BACIT-POLYMIX EYE OIBAU        4    GM
# 48559.0  6.131406e+10  NEOMYCIN-POLYMYXIN-HC EAR SFAL       10    ML
# 48563.0  6.498001e+10  PROBENECID-COLCHICINE TABS RIS      100    TA
# 50631.0  9.046341e+08  METOPROLOL TARTRATE 25 MG TMAJ     1000    TA
# 52193.0  4.091559e+08         MARCAINE 0.25% VIAL HOS       10    ML
# 58193.0  5.128501e+10  PLAN B ONE-STEP 1.5 MG TABLDMD        1    TA
# 59178.0  9.045461e+08  OYSTER SHELL 500-VIT D3 200MAJ     1000    TA
# 59211.0  9.355180e+07     SILDENAFIL 20 MG TABLET TEV       90    TA
# 59510.0  5.361024e+08  CALCIUM CARBONATE 648 MG TARUG     1000    TA
# 61717.0  5.740508e+08  FERROUS GLUCONATE 324 MG TAPAD      100    TA
# 62240.0  1.860917e+08  PULMICORT 90 MCG FLEXHALER AST        1    EA
# 62241.0  1.860916e+08  PULMICORT 180 MCG FLEXHALERAST        1    EA
# 62533.0  4.338601e+10         GAVILYTE-G SOLUTION GAV     4000    ML
# 62710.0  6.498100e+06  RECOMBIVAX HB 5 MCG/0.5 ML MSD        1    ML
# 63901.0  4.928104e+10         ADACEL TDAP SYRINGE ATP        1    ML
# 63909.0  6.483141e+06  VAQTA 25 UNITS/0.5 ML VIAL MSD        1    ML
# 64302.0  9.046158e+08  VITAMIN D3 2,000 UNIT TABLEMAJ      100    TA
# 66517.0  5.970260e+08  GLUCAGEN DIAGNOSTIC 1 MG VIB-I        1    EA
# 68182.0  1.093906e+10              PRENATAL TABLET MC      100    TA
# 71203.0  5.128502e+10        PARAGARD T 380-A IUD DMD        1    EA
#
#         gcsn_totals                 units_per_rx                     ...      \
#            rx_count tot_units   qoh         mean      25%     50%    ...
# gcsn                                                                 ...
# 266.0           4.0     240.0    90    60.000000    30.00    60.0    ...
# 287.0           0.0       0.0   500          NaN      NaN     NaN    ...
# 346.0           2.0     360.0   160   180.000000   180.00   180.0    ...
# 390.0          34.0    2415.0  2410    71.029412    54.75    90.0    ...
# 391.0          68.0    5300.0  3217    77.941176    49.25    90.0    ...
# 392.0          71.0    5192.0   749    73.126761    60.00    90.0    ...
# 393.0          31.0    2406.0  1577    77.612903    30.00    90.0    ...
# 475.0          13.0    1300.0   400   100.000000   100.00   100.0    ...
# 564.0           0.0       0.0   685          NaN      NaN     NaN    ...
# 566.0           0.0       0.0   100          NaN      NaN     NaN    ...
# 573.0           3.0     341.0   500   113.666667    80.50   101.0    ...
# 1275.0          7.0     367.0  2277    52.428571    36.00    55.0    ...
# 1276.0          7.0     503.0   538    71.857143    22.50    60.0    ...
# 1408.0          3.0     210.0   290    70.000000    60.00    90.0    ...
# 1645.0         30.0    3699.0  2346   123.300000    66.00    90.0    ...
# 1774.0         18.0    1194.0   939    66.333333    40.50    60.0    ...
# 1775.0         36.0    6039.0  3147   167.750000    90.00   180.0    ...
# 1990.0          0.0       0.0  1200          NaN      NaN     NaN    ...
# 2151.0         16.0    1532.0   640    95.750000    44.25    90.0    ...
# 2169.0          0.0       0.0    84          NaN      NaN     NaN    ...
# 2184.0          0.0       0.0   200          NaN      NaN     NaN    ...
# 2329.0          0.0       0.0    25          NaN      NaN     NaN    ...
# 2336.0          0.0       0.0  1170          NaN      NaN     NaN    ...
# 2337.0         15.0     961.0   307    64.066667    10.50    90.0    ...
# 2366.0         11.0     718.0  1041    65.272727    45.00    60.0    ...
# 2391.0          2.0      90.0   206    45.000000    37.50    45.0    ...
# 2421.0          5.0     330.0   451    66.000000    30.00    90.0    ...
# 2451.0          6.0     390.0  1813    65.000000    60.00    60.0    ...
# 2532.0         61.0    4441.0  3295    72.803279    60.00    90.0    ...
# 2535.0          0.0       0.0   200          NaN      NaN     NaN    ...
# ...             ...       ...   ...          ...      ...     ...    ...
# 46237.0         6.0     678.0   342   113.000000    51.00    90.0    ...
# 46238.0        27.0    2680.0  1822    99.259259    60.00    90.0    ...
# 46239.0         0.0       0.0   300          NaN      NaN     NaN    ...
# 46241.0        10.0     577.0  2129    57.700000    22.00    37.5    ...
# 46242.0         5.0     394.0   944    78.800000    60.00    60.0    ...
# 46403.0         0.0       0.0   339          NaN      NaN     NaN    ...
# 46405.0         1.0     180.0    90   180.000000   180.00   180.0    ...
# 46450.0         6.0     660.0   240   110.000000    90.00    90.0    ...
# 46754.0        42.0    7642.0  2342   181.952381   120.00   180.0    ...
# 47400.0         3.0      40.0   240    13.333333    10.00    10.0    ...
# 48544.0         1.0       4.0     8     4.000000     4.00     4.0    ...
# 48559.0         0.0       0.0    20          NaN      NaN     NaN    ...
# 48563.0         0.0       0.0   200          NaN      NaN     NaN    ...
# 50631.0        20.0    2472.0   350   123.600000    60.00   124.0    ...
# 52193.0         1.0      10.0    90    10.000000    10.00    10.0    ...
# 58193.0         0.0       0.0     1          NaN      NaN     NaN    ...
# 59178.0        11.0     938.0   520    85.272727    73.00    90.0    ...
# 59211.0         8.0     138.0   255    17.250000     7.25    12.5    ...
# 59510.0         5.0     547.0  1453   109.400000    90.00    90.0    ...
# 61717.0         4.0     384.0   516    96.000000    70.50    87.0    ...
# 62240.0         0.0       0.0     6          NaN      NaN     NaN    ...
# 62241.0         2.0       2.0    16     1.000000     1.00     1.0    ...
# 62533.0         2.0    8000.0  4000  4000.000000  4000.00  4000.0    ...
# 62710.0         0.0       0.0     0          NaN      NaN     NaN    ...
# 63901.0         1.0       1.0     9     1.000000     1.00     1.0    ...
# 63909.0         0.0       0.0    10          NaN      NaN     NaN    ...
# 64302.0        12.0     840.0   870    70.000000    52.50    75.0    ...
# 66517.0         0.0       0.0     1          NaN      NaN     NaN    ...
# 68182.0        21.0    1341.0   362    63.857143    30.00    90.0    ...
# 71203.0         0.0       0.0     1          NaN      NaN     NaN    ...
#
#         rx_units_per_day   per_clinic                                       \
#                      max         mean         std     min      25%     50%
# gcsn
# 266.0           1.000000    80.000000   17.320508    60.0    75.00    90.0
# 287.0                NaN          NaN         NaN     NaN      NaN     NaN
# 346.0           2.000000   180.000000    0.000000   180.0   180.00   180.0
# 390.0           2.000000    92.884615   56.782622     7.0    60.00    90.0
# 391.0           2.000000   143.243243   80.066433     7.0    90.00   120.0
# 392.0           1.000000   123.619048   75.776936     7.0    90.00    90.0
# 393.0           3.000000   150.375000  169.712256    15.0    60.00    90.0
# 475.0           3.333333   130.000000   67.494856   100.0   100.00   100.0
# 564.0                NaN          NaN         NaN     NaN      NaN     NaN
# 566.0                NaN          NaN         NaN     NaN      NaN     NaN
# 573.0           2.020000   113.666667   60.994535    60.0    80.50   101.0
# 1275.0          1.000000    61.166667   18.755444    41.0    47.50    57.5
# 1276.0          2.016667    83.833333   62.524928     7.0    41.25    82.5
# 1408.0          1.000000    70.000000   34.641016    30.0    60.00    90.0
# 1645.0          3.018868   184.950000  192.557162     7.0    75.00   132.0
# 1774.0          2.000000    91.846154   52.170947    30.0    60.00    90.0
# 1775.0          6.000000   241.560000  159.666340    14.0   120.00   180.0
# 1990.0               NaN          NaN         NaN     NaN      NaN     NaN
# 2151.0          3.000000   117.846154   84.689478    30.0    90.00    90.0
# 2169.0               NaN          NaN         NaN     NaN      NaN     NaN
# 2184.0               NaN          NaN         NaN     NaN      NaN     NaN
# 2329.0               NaN          NaN         NaN     NaN      NaN     NaN
# 2336.0               NaN          NaN         NaN     NaN      NaN     NaN
# 2337.0          1.000000    68.642857   42.118162     1.0    32.25    90.0
# 2366.0          4.000000    71.800000   25.147564    30.0    60.00    89.0
# 2391.0          1.000000    45.000000   21.213203    30.0    37.50    45.0
# 2421.0          1.000000    66.000000   32.863353    30.0    30.00    90.0
# 2451.0          1.000000    65.000000   22.583180    30.0    60.00    60.0
# 2532.0          1.500000   138.781250   78.244338    10.0    82.50   127.5
# 2535.0               NaN          NaN         NaN     NaN      NaN     NaN
# ...                  ...          ...         ...     ...      ...     ...
# 46237.0         3.000000   135.600000   91.743120    48.0    60.00   120.0
# 46238.0         4.000000   157.647059   88.194346     4.0   120.00   180.0
# 46239.0              NaN          NaN         NaN     NaN      NaN     NaN
# 46241.0         2.000000    72.125000   55.449945    15.0    37.75    52.5
# 46242.0         1.500000    78.800000   34.924204    49.0    60.00    60.0
# 46403.0              NaN          NaN         NaN     NaN      NaN     NaN
# 46405.0         2.000000   180.000000         NaN   180.0   180.00   180.0
# 46450.0         2.000000   132.000000   69.065187    30.0    90.00   180.0
# 46754.0         4.000000   332.260870  333.060903    90.0   170.00   280.0
# 47400.0         0.333333    13.333333    5.773503    10.0    10.00    10.0
# 48544.0         0.400000     4.000000         NaN     4.0     4.00     4.0
# 48559.0              NaN          NaN         NaN     NaN      NaN     NaN
# 48563.0              NaN          NaN         NaN     NaN      NaN     NaN
# 50631.0         2.000000   164.800000   53.696502    28.0   166.00   180.0
# 52193.0        10.000000    10.000000         NaN    10.0    10.00    10.0
# 58193.0              NaN          NaN         NaN     NaN      NaN     NaN
# 59178.0         2.000000    85.272727   31.359499    32.0    73.00    90.0
# 59211.0         1.000000    17.250000   13.864137     4.0     7.25    12.5
# 59510.0         2.000000   109.400000   72.813460     7.0    90.00    90.0
# 61717.0         2.000000    96.000000   62.161081    30.0    70.50    87.0
# 62240.0              NaN          NaN         NaN     NaN      NaN     NaN
# 62241.0         0.033333     1.000000    0.000000     1.0     1.00     1.0
# 62533.0      4000.000000  4000.000000    0.000000  4000.0  4000.00  4000.0
# 62710.0              NaN          NaN         NaN     NaN      NaN     NaN
# 63901.0         1.000000     1.000000         NaN     1.0     1.00     1.0
# 63909.0              NaN          NaN         NaN     NaN      NaN     NaN
# 64302.0         1.000000    76.363636   28.025962    30.0    60.00    90.0
# 66517.0              NaN          NaN         NaN     NaN      NaN     NaN
# 68182.0         1.000000    89.400000   76.738703    20.0    31.00    90.0
# 71203.0              NaN          NaN         NaN     NaN      NaN     NaN
#
#
#              75%     max rx_cnt_mean rx_cnt_max
# gcsn
# 266.0      90.00    90.0    1.333333        2.0
# 287.0        NaN     NaN         NaN        NaN
# 346.0     180.00   180.0    1.000000        1.0
# 390.0      90.00   260.0    1.307692        3.0
# 391.0     180.00   300.0    1.837838        6.0
# 392.0     180.00   280.0    1.690476        5.0
# 393.0     180.00   690.0    1.937500        7.0
# 475.0     100.00   300.0    1.300000        3.0
# 564.0        NaN     NaN         NaN        NaN
# 566.0        NaN     NaN         NaN        NaN
# 573.0     140.50   180.0    1.000000        1.0
# 1275.0     72.00    90.0    1.166667        2.0
# 1276.0    113.25   180.0    1.166667        2.0
# 1408.0     90.00    90.0    1.000000        1.0
# 1645.0    232.50   810.0    1.500000        4.0
# 1774.0    105.00   180.0    1.384615        2.0
# 1775.0    360.00   720.0    1.440000        4.0
# 1990.0       NaN     NaN         NaN        NaN
# 2151.0    135.00   363.0    1.230769        2.0
# 2169.0       NaN     NaN         NaN        NaN
# 2184.0       NaN     NaN         NaN        NaN
# 2329.0       NaN     NaN         NaN        NaN
# 2336.0       NaN     NaN         NaN        NaN
# 2337.0     90.00   120.0    1.071429        2.0
# 2366.0     90.00    90.0    1.100000        2.0
# 2391.0     52.50    60.0    1.000000        1.0
# 2421.0     90.00    90.0    1.000000        1.0
# 2451.0     82.50    90.0    1.000000        1.0
# 2532.0    187.50   290.0    1.906250        3.0
# 2535.0       NaN     NaN         NaN        NaN
# ...          ...     ...         ...        ...
# 46237.0   180.00   270.0    1.200000        2.0
# 46238.0   210.00   270.0    1.588235        4.0
# 46239.0      NaN     NaN         NaN        NaN
# 46241.0    97.50   180.0    1.250000        2.0
# 46242.0    90.00   135.0    1.000000        1.0
# 46403.0      NaN     NaN         NaN        NaN
# 46405.0   180.00   180.0    1.000000        1.0
# 46450.0   180.00   180.0    1.200000        2.0
# 46754.0   360.00  1640.0    1.826087        7.0
# 47400.0    15.00    20.0    1.000000        1.0
# 48544.0     4.00     4.0    1.000000        1.0
# 48559.0      NaN     NaN         NaN        NaN
# 48563.0      NaN     NaN         NaN        NaN
# 50631.0   180.00   240.0    1.333333        3.0
# 52193.0    10.00    10.0    1.000000        1.0
# 58193.0      NaN     NaN         NaN        NaN
# 59178.0    90.00   160.0    1.000000        1.0
# 59211.0    24.00    40.0    1.000000        1.0
# 59510.0   180.00   180.0    1.000000        1.0
# 61717.0   112.50   180.0    1.000000        1.0
# 62240.0      NaN     NaN         NaN        NaN
# 62241.0     1.00     1.0    1.000000        1.0
# 62533.0  4000.00  4000.0    1.000000        1.0
# 62710.0      NaN     NaN         NaN        NaN
# 63901.0     1.00     1.0    1.000000        1.0
# 63909.0      NaN     NaN         NaN        NaN
# 64302.0    90.00   120.0    1.090909        2.0
# 66517.0      NaN     NaN         NaN        NaN
# 68182.0    90.00   270.0    1.400000        4.0
# 71203.0      NaN     NaN         NaN        NaN
#
# [254 rows x 23 columns]
